# %% [markdown]
# <a href="https://colab.research.google.com/github/paulodowd/BLE_WiFi_LocalisationTests/blob/main/BLE_and_WiFi_Scanning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We will use the following Python libraries:
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('https://raw.githubusercontent.com/paulodowd/BLE_WiFi_LocalisationTests/refs/heads/main/results/scanning_results.csv', sep=',')
print(df)
# Out:
#              condition  distance    dt  db
# 0           BLE_tx_0db       0.0    12 -35
# 1           BLE_tx_0db       0.0  4030 -36
# 2           BLE_tx_0db       0.0  2037 -35
# 3           BLE_tx_0db       0.0   984 -36
# 4           BLE_tx_0db       0.0  1046 -36
# ...                ...       ...   ...  ..
# 23445  Netgear_Wifi_AP      10.0    62 -59
# 23446  Netgear_Wifi_AP      10.0    61 -59
# 23447  Netgear_Wifi_AP      10.0    62 -60
# 23448  Netgear_Wifi_AP      10.0    61 -59
# 23449  Netgear_Wifi_AP      10.0    61 -59
#
# [23450 rows x 4 columns]

# %%
colours = dict(zip(df['condition'].unique(), sns.color_palette(n_colors=len(df['condition'].unique()))))

lplot = sns.relplot(data=df, x='distance', y='db', kind='line', hue='condition', palette=colours, height=5, aspect=2, errorbar=('ci',95) )
# Set y-axis limits
#lplot.set(ylim=(0, 1))
#plt.axhline(320, ls='--', linewidth=1, color='red')
plt.show()

# %%
colours = dict(zip(df['condition'].unique(), sns.color_palette(n_colors=len(df['condition'].unique()))))

lplot = sns.relplot(data=df, x='distance', y='db', kind='line', hue='condition', palette=colours, height=5, aspect=2, errorbar=('ci',95) )
# Set y-axis limits
lplot.set(xlim=(0, 5))
#plt.axhline(320, ls='--', linewidth=1, color='red')
plt.show()
